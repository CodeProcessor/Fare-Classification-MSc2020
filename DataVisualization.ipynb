# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_filename = 'data/train.csv'
train_df = pd.read_csv(train_filename)
train_df.dropna(inplace=True)
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16968 entries, 0 to 17175
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   tripid                     16968 non-null  int64
#  1   additional_fare            16968 non-null  float64
#  2   duration                   16968 non-null  float64
#  3   meter_waiting              16968 non-null  float64
#  4   meter_waiting_fare         16968 non-null  float64
#  5   meter_waiting_till_pickup  16968 non-null  float64
#  6   pickup_time                16968 non-null  object
#  7   drop_time                  16968 non-null  object
#  8   pick_lat                   16968 non-null  float64
#  9   pick_lon                   16968 non-null  float64
#  10  drop_lat                   16968 non-null  float64
#  11  drop_lon                   16968 non-null  float64
#  12  fare                       16968 non-null  float64
# ...

# %%
sns.lmplot("duration", "fare", data=train_df, fit_reg=False, col='label', col_wrap=2, ci=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1d6ea5800370> in <module>
#       1 #sns.lmplot("duration", "fare", data=train_df, fit_reg=False, col='label', col_wrap=2, ci=5)
# ----> 2 aqwe
#
# NameError: name 'aqwe' is not defined

# %%
sub_df = train_df[train_df['label'] == 'incorrect']

useful_colomns_2 = ["additional_fare", "duration", "meter_waiting", "meter_waiting_fare", "fare"]
df1 = sub_df[useful_colomns_2]

# df1['Produced Qty'] = df1['Produced Qty'].astype(float)
corr = df1.loc[:,df1.dtypes == 'float64'].corr()
ax = plt.axes()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, 
            cmap=sns.diverging_palette(220, 10, as_cmap=True), annot=True, ax = ax)
